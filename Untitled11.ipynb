# %%
import zipfile, os
import pandas as pd
#找到压缩包所在位置
os.chdir('H:\\')
read_c = zipfile.ZipFile('bd.zip','r')
#打开压缩文件
f=read_c.open('bd2019-weather-prediction-training-20190608.csv',mode='r',pwd='Zp7Y'.encode('ascii'))
#加载csv文件
df=pd.read_csv(f)

#日期格式化
df['date']=pd.to_datetime(df['date'],format='%Y%m%d')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from dateutil.parser import parser

from datetime import datetime

# %%
a=df.loc[df['city'] == 'A']
b=df.loc[df['city'] == 'B']
c=df.loc[df['city'] == 'C']

sta=b.loc[b.station==201]
b_inner=sta.set_index('date')

b1=b_inner[:'2013-01-30']
y1=b1.humidity

y2=b1.temperature

y1
# Out:
# date
# 2013-01-01    39.0
# 2013-01-02    50.0
# 2013-01-03    61.0
# 2013-01-04    71.0
# 2013-01-05    68.0
# 2013-01-06    76.0
# 2013-01-07    72.0
# 2013-01-08    62.0
# 2013-01-09    60.0
# 2013-01-10    56.0
# 2013-01-11    59.0
# 2013-01-12    65.0
# 2013-01-13    68.0
# 2013-01-14    61.0
# 2013-01-15    74.0
# 2013-01-16    70.0
# 2013-01-17    59.0
# 2013-01-18    58.0
# 2013-01-19    64.0
# 2013-01-20    81.0
# 2013-01-21    83.0
# 2013-01-22    82.0
# 2013-01-23    87.0
# 2013-01-24    81.0
# 2013-01-25    71.0
# 2013-01-26    86.0
# 2013-01-27    81.0
# 2013-01-28    66.0
# 2013-01-29    65.0
# 2013-01-30    70.0
# Name: humidity, dtype: float64

# %%
fig, ax = plt.subplots()
plt.xticks(rotation=30)
plt.xlabel("date")
plt.ylabel("humidity")
plt.title("tianqifenxi")
ax.plot(y1, 'r')

# %%
fig, ax = plt.subplots()
plt.xticks(rotation=30)
plt.xlabel("date")
plt.ylabel("temperture")
plt.title("tianqifenxi")
ax.plot(y2, 'g')
